# %% [markdown]
# # Team Sigma - Project 1
#
# ### Propuestas de proyecto:
# * Sustentar la tesis que se va a morir más gente de hambre que de COVID
# * Derivado de la regresión de la curva de expectativa de vida (consumo de proteína) vs la regresión económica causada por el COVID
# * Consumo de alimento
# * Buscar el índice de bancarización por estados vs el crecimiento de GDP por región
# * Tarjetas de crédito por región
# * Fintecs
# * Desmitificación del COVID
# * Mitos de temperatura Grados Celsius
# * Mito del ingreso per cápita vs muertes por millón
#
# ### Próximos pasos:
# * Encontrar los Data Sets
# * Evolución histórica del consumo de proteína por país / Expectativa de vida - Juanfer
# * GPD per cápita del país histórico - Jorge
# * Temperatura promedio por país ? Por regiones del mundo ? Ciudades en específico que determinen la temperatura de la zona ? - Ivan
# * APIs COVID.
# * Muertes - Luis
# * Población total de las zonas - Daniel

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\luis\dropbox\personal\dataanalytics\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import os

# %%
file_path = os.path.join("Resources", "owid-covid-data.csv")
covid_df = pd.read_csv(file_path)
covid_df.shape
# Out:
# (52222, 41)

# %%
covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
covid_country_deaths_df = pd.DataFrame(covid_df.groupby("location")["total_deaths"].sum())
covid_country_deaths_df
# Out:
#                 total_deaths
# location
# Afghanistan         173384.0
# Albania              33364.0
# Algeria             215824.0
# Andorra              10169.0
# Angola               13081.0
# ...                      ...
# Western Sahara         148.0
# World            122584149.0
# Yemen                67299.0
# Zambia               28205.0
# Zimbabwe             17157.0
#
# [213 rows x 1 columns]

# %%
file_path = os.path.join("Resources", "life-expectancy.csv")
life_expentacy_df = pd.read_csv(file_path)
life_expentacy_df.shape
# Out:
# (19028, 4)

# %%
life_expentacy_df
# Out:
#             Entity Code  Year  Life expectancy
# 0      Afghanistan  AFG  1950           27.638
# 1      Afghanistan  AFG  1951           27.878
# 2      Afghanistan  AFG  1952           28.361
# 3      Afghanistan  AFG  1953           28.852
# 4      Afghanistan  AFG  1954           29.350
# ...            ...  ...   ...              ...
# 19023     Zimbabwe  ZWE  2015           59.534
# 19024     Zimbabwe  ZWE  2016           60.294
# 19025     Zimbabwe  ZWE  2017           60.812
# 19026     Zimbabwe  ZWE  2018           61.195
# 19027     Zimbabwe  ZWE  2019           61.490
#
# [19028 rows x 4 columns]

# %%
file_path = os.path.join("Resources", "WEOOct2020all.xlsx")
gdp_df = pd.read_excel(file_path)
gdp_df.shape
# Out:
# (8777, 56)

# %%
gdp_df.columns
# Out:
# Index([             'WEO Country Code',                           'ISO',
#                     'WEO Subject Code',                       'Country',
#                   'Subject Descriptor',                 'Subject Notes',
#                                'Units',                         'Scale',
#        'Country/Series-specific Notes',                            1980,
#                                   1981,                            1982,
#                                   1983,                            1984,
#                                   1985,                            1986,
#                                   1987,                            1988,
#                                   1989,                            1990,
#                                   1991,                            1992,
#                                   1993,                            1994,
#                                   1995,                            1996,
# ...

# %%
gdp_df["Units"].unique()
# Out:
# array(['National currency', 'Percent change', 'U.S. dollars',
#        'Purchasing power parity; international dollars', 'Index',
#        'Purchasing power parity; 2017 international dollar',
#        'Percent of potential GDP', 'Percent',
#        'National currency per current international dollar',
#        'Percent of GDP', 'Percent of total labor force', 'Persons', nan],
#       dtype=object)

# %%
#gdp_2019 = gdp_df[2019].notna()
#gdp_2020 = gdp_df[2020].notna()
gdp_data_df = gdp_df.iloc[:,[3,6,7,48,49,4,5]]
gdp_data_df = gdp_data_df.loc[gdp_data_df["Country"]=="Afghanistan"]
gdp_data_df
# Out:
#         Country                                              Units     Scale  \
# 0   Afghanistan                                  National currency  Billions
# 1   Afghanistan                                     Percent change       NaN
# 2   Afghanistan                                  National currency  Billions
# 3   Afghanistan                                       U.S. dollars  Billions
# 4   Afghanistan     Purchasing power parity; international dollars  Billions
# 5   Afghanistan                                              Index       NaN
# 6   Afghanistan                                  National currency     Units
# 7   Afghanistan  Purchasing power parity; 2017 international do...     Units
# 8   Afghanistan                                  National currency     Units
# 9   Afghanistan                                       U.S. dollars     Units
# 10  Afghanistan     Purchasing power parity; international dollars     Units
# ...
