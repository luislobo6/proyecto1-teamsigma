# %%
import pandas as pd

# %%
dataJF = "Resources/datos.csv"
dataJF = pd.read_csv(dataJF)

# %%
datos_df =pd.DataFrame(dataJF)

# %%
datos_df
# Out:
#      Año     Population  GDPcons GDPConsPPP PC_GDPcons PC_GDPConsPPP  Growth  \
# 0   1980  4,458,002,944   11,162     13,348      2,504         2,994   2.080
# 1   1981  4,536,996,864   11,442     14,858      2,522         3,275   1.876
# 2   1982  4,617,387,008   11,234     15,808      2,433         3,424   0.479
# 3   1983  4,699,569,152   11,531     16,833      2,454         3,582   2.706
# 4   1984  4,784,011,776   11,941     18,200      2,496         3,804   4.533
# 5   1985  4,870,922,240   12,471     19,435      2,560         3,990   3.581
# 6   1986  4,960,567,808   14,698     20,522      2,963         4,137   3.671
# 7   1987  5,052,521,984   16,921     21,835      3,349         4,322   3.915
# 8   1988  5,145,425,920   19,031     23,622      3,699         4,591   4.651
# 9   1989  5,237,441,024   20,019     25,448      3,822         4,859   3.793
# 10  1990  5,327,230,976   23,540     27,478      4,419         5,158   3.491
# ...
